# %% [markdown]
# ### Obtain data from Wiki Page

# %%
# !conda install -c conda-forge folium
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
# Import necessary libraries
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
import folium

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

#Create a handle, page, to handle the contents of the website
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')
table = soup.find('table')
trs = table.find_all('tr')
rows = []
for tr in trs:
    i = tr.find_all('td')
    if i:
        rows.append(i)
        
lst = []
for row in rows:
    postalcode = row[0].text.rstrip()
    borough = row[1].text.rstrip()
    neighborhood = row[2].text.rstrip()
    if borough != 'Not assigned':
        if neighborhood == 'Not assigned':
            neighborhood = borough
        lst.append([postalcode, borough, neighborhood])
        
cols = ['PostalCode', 'Borough', 'Neighborhood']
df = pd.DataFrame(lst, columns=cols)

df = df.groupby(['PostalCode', 'Borough'], as_index=False).agg(lambda neighborhoods: ', '.join(neighborhoods))

# %% [markdown]
# ### Add latitude and longitude of each neighborhood

# %%
# Since it is not able to obtain coordinates from using geocoder.google, the given csv file is used
# !wget -O GeoCord.csv http://cocl.us/Geospatial_data/
# Out:
# --2020-01-05 18:33:06--  http://cocl.us/Geospatial_data/
# Resolving cocl.us (cocl.us)... 169.48.113.194
# Connecting to cocl.us (cocl.us)|169.48.113.194|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data/ [following]
# --2020-01-05 18:33:06--  https://cocl.us/Geospatial_data/
# Connecting to cocl.us (cocl.us)|169.48.113.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-01-05 18:33:07--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.26.197, 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-01-05 18:33:08--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-01-05 18:33:08--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 185.235.236.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|185.235.236.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!zqHA0MborgvwW5-CAA1pSVgufuMRaQV5MwNasgNvxpllMTb-rrVNoBvKPmnWWyn1o6zUYi91OpWHrlAK1TmbRmWUj44SpfeVnR_aapH6L8xecZzVoMzuewMns3w13nYYxwIOKUdH0pM2ZesgoZg3y1Dhmmt7kKSij69nFUlv4sVo0oN8zAlEK9GnqH5jJXvss4hYwenJQujC6eJTW4IMKAIbwbJ8h1Twziks2NeoYbih5Wop43Vr__MIriMPc3UZOqioCNeSL232-e4_SjWy8qT2_dWgDxwIiSd-MdgjFkUHFg-JTaWw-qsD5k8xZW1vDjoeDVmgOgaAVo4b75icquitOagEt1epC5Pwt_n_LRQfbHHpWw_SBILC2gbGzvWhSZKCPu1usmXlMobd_zOzjvzAXHu_0o11ORW-tblwpiB0w_wsdH1jUf8A1KrwDImDOLsw2BKtx0Whj-YIN_WN1ZG8e8noOZDpwtR3QJ8XWJ1CS4hkt6C8LT2ISPFIpbZhzLrZQBjwoH3Lub7J0JlTaP-Mpk7mtzohpW0cONdZ3hT8LLECzXIz-3zGvI3g8Eoy-Vowzb4CZ9BVoOAxBf0SgSciZAEk8CNpBfi9rs4sQ3dvZsi9zStzx29w1mYkt6Zsl5MeLOlfGbqEL5cbbXqWJKfEtgfWOi9pLsrUrR9SZN
qrN7pV4yAz7nQSGdxJtQPvjm7FKxS5G5lYiQCyVcyyiTdpfalGUv3eAehVf3F4aJy7GqOVEZOlekHJ7H7vRXPt-Eyr5yS-QQ2LOTQrOPphYetBmTmKEWFRouU9gy-JfDp-JzFxg5dggtHO26SjNIepblI-ynX1Oay9476c_7TR8sQICM47UwSt4U5r6FLL3m7jhfpxxWD2guQLjKEv-obiksKqBX1SIWia0S6DVo5gGdut80pAQWNFDNqwgrYU9bkDRwY0J0-owa03XJOcUQoBmkDPdx2VOzOidYrVomP8KBXaJx15eD5h0nogQS7YztWAPfMkqILIlCMzxTfi-Y8ouG7otPUuOpaE13xIuUcdC9SfOhLPZ4PECgZDPaoYh9qy81hZ04rKwi5yMofkrPOhpKO1h6nucr-qIrKDGrPvJooNZx0jBaVowYAFM86b0c5ukQecSKHlIBsCnXXS93YJMUnzldVzoIoZVpfHRCtlINB1R5YNjtCW2Rlt7RSEuerKG_HEKdYQtMxyKuJnsz7Ej4jairDw908KgVP35y2p1KarSqpECcjjmgmniYPc02Rwsg3Le3MwDtXY3qLeFVm6zMTFIppvcU_6S5pfNjQBV9_o_HPyInVmJS6qX7eN0p3m4PE9cMnH90G6oFwixu58kNQFyN0wcRoa03xrc9ilLI0_36lSlyYdCOhAR5HwsSU71scwyczfbQ../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 185.235.236.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|185.235.236.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘GeoCord.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2020-01-05 18:33:09 (279 MB/s) - ‘GeoCord.csv’ saved [2891/2891]

# %%
df_cord = pd.read_csv('GeoCord.csv') # Read the csv data
df_cord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Create Latitude and Longitude columns in df_assigned
df['Latitude'] = np.nan
df['Longitude'] = np.nan

# For each postcode in df_assigned, find corresponding coordinates in df_cord and assign it to df_assigned
for idx in df.index:
    cord_idx = df_cord['Postal Code'] == df.loc[idx, 'PostalCode']
    df.at[idx, 'Latitude'] = df_cord.loc[cord_idx, 'Latitude'].values
    df.at[idx, 'Longitude'] = df_cord.loc[cord_idx, 'Longitude'].values

# Display the results
df.head(20)
# Out:
#    PostalCode      Borough                                       Neighborhood  \
# 0         M1B  Scarborough                                     Rouge, Malvern
# 1         M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2         M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                             Woburn
# 4         M1H  Scarborough                                          Cedarbrae
# 5         M1J  Scarborough                                Scarborough Village
# 6         M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 7         M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 8         M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 9         M1N  Scarborough                        Birch Cliff, Cliffside West
# 10        M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 11        M1R  Scarborough                                  Maryvale, Wexford
# 12        M1S  Scarborough                                          Agincourt
# 13        M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# 14        M1V  Scarborough  Agincourt North, L'Amoreaux East, Milliken, St...
# 15        M1W  Scarborough                                    L'Amoreaux West
# 16        M1X  Scarborough                                        Upper Rouge
# 17        M2H   North York                                  Hillcrest Village
# 18        M2J   North York                       Fairview, Henry Farm, Oriole
# 19        M2K   North York                                    Bayview Village
#
#      Latitude  Longitude
# 0   43.806686 -79.194353
# 1   43.784535 -79.160497
# 2   43.763573 -79.188711
# 3   43.770992 -79.216917
# 4   43.773136 -79.239476
# 5   43.744734 -79.239476
# 6   43.727929 -79.262029
# 7   43.711112 -79.284577
# 8   43.716316 -79.239476
# 9   43.692657 -79.264848
# 10  43.757410 -79.273304
# 11  43.750072 -79.295849
# 12  43.794200 -79.262029
# 13  43.781638 -79.304302
# 14  43.815252 -79.284577
# 15  43.799525 -79.318389
# 16  43.836125 -79.205636
# 17  43.803762 -79.363452
# 18  43.778517 -79.346556
# 19  43.786947 -79.385975

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df['Borough'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %%
# create map of Toronto using latitude and longitude values
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="can_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, df in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(df, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
